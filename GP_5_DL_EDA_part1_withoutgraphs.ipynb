# %% [markdown]
# # Современные методы анализа данных и машинного обучения, БИ
#
# ## НИУ ВШЭ, 2025-26 учебный год

# %% [markdown]
# ## Групповой проект №5. Deep Learning

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Дата выдачи:__ 25.05.2026
#
# __Дедлайн по записи в таблицу:__ 4:00 03.06.2026
#
# __Дедлайн по загрузке работ:__ 4:00 15.06.2026
#
# __Защита проекта:__ ~

# %% [markdown]
# ## Формат выполнения

# %% [markdown]
# Групповой проект представляет собой творческое инициативное групповое задание, которое выполняется студентами в командах от 3 до 6 человек. В то же время следует помнить, что чем больше в команде людей, тем выше предъявляются требования в целом к команде, а также к выполняемому ею проекту. Команды разрешается формировать из студентов разных групп.
#
# При оценивании результатов выполнения проекта командой в обязательном порядке проверяется и учитывается в оценке вклад **каждого участника** в общую работу команды. Вследствие этого крайне важно ответственно подойти к выбору сокомандников, распределению обязанностей внутри команды, а также пресечению наличия "мертвых душ" в команде.
#
# При необходимости команда большинством голосов имеет право исключить человека из команды **до загрузки работ** в систему [Anytask](https://anytask.org/), сообщив об этом преподавателю, в случае если такой человек никак не проявлялся в ходе выполнения проекта и являлся как раз таки той самой "мертвой душой". Помните про эту возможность, поскольку наличие "мертвых душ" может негативно повлиять на качество и оценку для всего проекта и, как следствие, в целом для всей команды!
#
# Запись составов команд осуществляется по ссылке в таблице:
#
# https://docs.google.com/spreadsheets/d/16IB8mURLGKoipq0Jld6wOGPMpJbRQ8GCkSZKbIP-XYA/edit?usp=sharing

# %% [markdown]
# ## Отправка материалов группового проекта

# %% [markdown]
# Во избежание использования при выполнении группового проекта генеративных моделей (ChatGPT и так далее) за рамками справочной и образовательной информации (то есть, например, для автоматической генерации кода по одному из этапов) **одному из участников команды** необходимо предварительно загрузить работу в систему [Anytask](https://anytask.org/). Наличие сгенерированного кода или любого другого случая "несанкционированного" использования нейросетей будет считаться плагиатом, и такой проект будет оценен в 0 баллов для всех участников. При отсутствии своевременно загруженных файлов с проектом команде также выставляется 0 за проект.
#
# *Примечание: презентацию проекта загружать необязательно, важно отправить содержательные файлы с кодом и ссылку на репозиторий GitHub.*

# %% [markdown]
# ## Оценивание и штрафы

# %% [markdown]
# Групповой проект оценивается исходя из устной защиты (презентации) командой выполненного ими проекта перед комиссией. Комиссия составляется из преподавателей курса, ассистентов курса, а также приглашенных экспертов из индустрии.
#
# В рамках каждой защиты комиссия выставляет два типа оценок.
#
# Первая оценка — это оценка для всего проекта в целом. Она ставится комиссией, исходя из глубины проработки командой предметной области, сложности применяемых в проекте инструментов, а также прочих аспектов, связанных с содержанием выполняемого в проекте ТЗ. При выставлении этой оценки комиссия ориентируется на критерии, более подробно представленные ниже в разделе "Критерии оценки проекта".
#
# Вторая оценка — это индивидуальная оценка каждого участника команды. Именно эта оценка выставляется впоследствии в ведомость. Индивидуальная оценка участника команды определяется комиссией, исходя из того, насколько участник ориентируется в выполненном командой проекте, как он отвечает на адресованные персонально ему вопросы комиссии, насколько в принципе прослеживается его роль в проекте, а также исходя из других аспектов, связанных с участием конкретного человека в деятельности команды. Индивидуальная оценка не может превосходить оценку команды за проект в целом (первую оценку), однако, в случае когда участник спокойно и корректно отвечает на все адресованные ему вопросы, свободно ориентируется в материале и содержании выполненного проекта, а также когда его роль в работе команды не вызывает сомнений, — в таком случае, индивидуальная оценка участника становится равной оценке для всего проекта (т.е. в идеальном случае — вторая оценка равна первой оценке). Кроме того, в исключительных случаях, при демонстрации участником на защите превосходящих ожидания уровней понимания, участия и вовлечения в рамках проекта, комиссия может своим решением повысить индивидуальную оценку для этого участника на 0,5 или 1 балл относительно общей оценки за проект (первой оценки).
#
# Во избежание субъективности и/или предвзятости оценки тех или иных членов комиссии в отношении тех или иных команд, а также каких-либо иных проявлений неравных условий — распределение команд между комиссиями осуществляется абсолютно рандомно с использованием средств библиотеки Numpy :)) — в качестве рэндом сида выступает дата, в которую производится распределение, например, `np.random.seed(25052026)`.
#
# Обратите, пожалуйста, внимание на то, что бОльшая часть комиссий осуществляет приём проектов в очной форме, однако могут присутствовать и 1-2 комиссии, которые будут работать дистанционно с использованием средств видеосвязи. В случае попадания команды путем случайного распределения в комиссию, работающую в очной форме, *не допускается* какое-либо изменение формата проведения для команды на онлайн-режим, равно как и любые другие перемещения команд между комиссиями (смены комиссий), для сохранения честности и непредвзятости случайного распределения.
#
# Явка студента на защиту проекта является обязательной; вклад студента без его присутствия не оценивается и автоматически является равным нулю. Для дистанционных комиссий дополнительным требованием является обязательное наличие включенной камеры в течение всего времени нахождения в конференции

# %% [markdown]
# ## Описание задания

# %% [markdown]
# В современной бизнес-индустрии использование глубинного обучения приобретает критическое значение. Компании активно внедряют нейронные сети для решения самых разных задач: от анализа структурированных табличных данных до работы с изображениями и текстами. Это позволяет бизнесу принимать более обоснованные решения и оперативно реагировать на изменения рынка.
#
# В данном проекте вы на реальных данных попрактикуетесь в построении и сравнении нейросетевых архитектур для решения двух бизнес-задач разной природы. Первая задача будет связана с табличными данными и решается с помощью полносвязных нейронных сетей. Вторая - с неструктурированными данными: изображениями или текстами, - и решается с помощью более сложных архитектур глубинного обучения. Помимо этого, вы получите опыт организации работы над ML-проектом так, как это принято в индустрии: с версионированием кода, воспроизводимыми экспериментами и сохранением всех артефактов.
#
# Принципиально важно, что обе бизнес-задачи должны быть **содержательно связаны между собой** и **относиться к одной и той же компании или платформе** — таким образом, чтобы вместе они образовывали единое и логически целостное решение для выбранного бизнес-контекста. Проект, в котором две задачи решаются для разных компаний или никак не связаны между собой, оценивается в **0 баллов** для всех участников команды.

# %% [markdown]
# ### Этапы проекта

# %% [markdown]
# Ниже вашему вниманию предлагаются примерные этапы реализации проекта:
#
# - Выбор компании и/или платформы;
# - Формулировка двух связанных бизнес-задач, которые могла бы хотеть решить компания/платформа на основе данных: одна на табличных данных, другая на неструктурированных (изображения или текст);
# - Обоснование сформулированных бизнес-задач и описание того, как предлагаемое решение вписывается в бизнес-процессы компании;
# - Получение необходимых данных путём поиска открытых источников/датасетов, парсинга/работы с API;
# - Формулировка задач в терминах глубинного обучения для решения поставленных бизнес-задач;
# - Выбор и обоснование архитектур нейронных сетей для каждой из задач;
# - Первичная обработка данных;
# - Построение, обучение и сравнение нейросетевых архитектур с обязательным логированием экспериментов;
# - Получение и агрегация результатов, финальные выводы.

# %% [markdown]
# ### Требования к проекту

# %% [markdown]
# В качестве результата выполнения группового проекта ваша команда должна получить презентацию и защитить её перед комиссией, а также предоставить ссылку на репозиторий GitHub с кодом.
#
# Оформление презентации остаётся полностью на ваше усмотрение, но помните, что результат должен быть релевантен для демонстрации бизнес-заказчику — комиссию, принимающую вашу работу, правильнее всего воспринимать именно в таком качестве. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не рекомендуется.
#
# С точки зрения концепции выполнения проекта, вам необходимо принять на себя роль дата-инженеров: продумать идеологию получения и извлечения данных; дата-аналитиков: соотнести бизнес-задачу с формулировками на языке данных; и главное, безусловно, — дата-сайентистов: реализовать поставленные задачи с помощью методов глубинного обучения и извлечь полезные инсайты из проделанной работы. А в конце, конечно, презентовать всю эту красоту в понятном виде потенциальному заказчику.
#
# Разумеется, чем сложнее и чем нетривиальнее будет ваша задача, а также чем глубже и чем осмысленнее будут выводы, извлечённые в рамках этой задачи, — тем выше окажется качество вашего проекта и тем выше он будет оценён!

# %% [markdown]
# ### Полезные замечания и советы

# %% [markdown]
# - Графики и визуализации — это очень хорошо — все любят графики
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев
# - Не нужно делать просто текстовые слайды
# - Стройте свой проект исходя из того, что ваша цель — представить полезную информацию для бизнеса
# - Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами

# %% [markdown]
# ## Критерии оценки проекта

# %% [markdown]
# Оценка за групповой проект в целом — то есть первая из двух оценок — выставляется по 10-балльной шкале, исходя из 5 критериев. Также комиссия на своё усмотрение может добавить (но не снизить) некоторое количество бонусных баллов за рамками данных критериев.
#
# Каждый из критериев будет перечислен и рассмотрен ниже.

# %% [markdown]
# ### Критерий 1. Выбор задач и бизнес-обоснование (до 2 баллов)
#
# Данный критерий оценивает, насколько обоснованными и осмысленными и **содержательно связанными** получились две решаемые в проекте бизнес-задачи; насколько полно был осуществлён переход от бизнес-задач к задачам глубинного обучения (насколько в реальности постановка задач соответствует исходной постановке задачи с точки зрения интересов компании); а также насколько корректными, объёмными и прикладными для бизнеса получились выявленные в ходе исследования инсайты.
#
# По данному критерию можно получить **максимальный балл** только при условии, что в презентации представлена схема, иллюстрирующая, как предлагаемое решение вписывается в бизнес-процессы компании: откуда поступают данные, каким образом они обрабатываются, как модель генерирует предсказания и каким образом эти предсказания используются для принятия бизнес-решений. Строгая нотация не обязательна — важна логика и понятность схемы для стороннего наблюдателя.

# %% [markdown]
# ### Критерий 2. Инструменты извлечения и обработки данных (до 1,5 баллов)
#
# Данный критерий оценивает техническую реализацию процесса сбора данных ручным и автоматизированным образом, использованные средства предобработки, подготовки данных и EDA. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным.

# %% [markdown]
# ### Критерий 3. Глубинное обучение на табличных данных (до 2 баллов)
#
# Данный критерий оценивает применение полносвязных нейронных сетей для решения бизнес-задачи на табличных данных. В рамках этого критерия будет рассматриваться корректность постановки задачи, осмысленность выбора архитектуры, качество предобработки данных, а также глубина сравнительного анализа различных конфигураций сети.
#
# *__Важно:__ в случае **оценки 0** за этот критерий оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить **отличное от нуля количество баллов** только при условии корректного применения полносвязной нейронной сети для решения поставленной задачи на табличных данных.*
#
# *По данному критерию можно получить **1 балл и выше** только при условии осуществления сравнительного анализа различных конфигураций и сложности архитектуры: должно быть рассмотрено не менее трёх вариантов, значимо отличающихся друг от друга — например, по глубине сети, размеру скрытых слоёв, функциям активации, наличию регуляризации. Использование каждой конфигурации, как и подбор гиперпараметров, должны быть подробно описаны и обоснованы; в рамках сравнения должны быть получены и сформулированы явные, значимые выводы о том, как изменение архитектуры влияет на качество решения задачи.*
#
# *По данному критерию можно получить **максимальный балл в 2 балла** только при условии корректного и обоснованного применения архитектурных решений или подходов, не рассматривавшихся в рамках соответствующих лекций и семинаров. Кроме того, **максимальный балл в 2 балла** по данному критерию недостижим без логирования экспериментов в соответствии с требованиями **Критерия 5**. При этом ожидается, что каждая из сравниваемых конфигураций залогирована отдельным запуском с сохранением параметров архитектуры и обучения, метрик качества, а также артефакта обученной модели, позволяющего воспроизвести её предсказания без повторного обучения.*

# %% [markdown]
# ### Критерий 4. Глубинное обучение на неструктурированных данных  (до 3 баллов)
#
# Данный критерий оценивает применение методов глубинного обучения для решения бизнес-задачи на неструктурированных данных: изображениях или текстах. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным. Кроме того, будет оценен сравнительный анализ архитектур нейронных сетей, использованных в решении.
#
# *__Важно:__ в случае **оценки 0** за этот критерий оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить **отличное от нуля количество баллов** только при условии использования в проекте сверточных нейронных сетей, рекуррентных нейронных сетей или же более сложных архитектур глубоких нейронных сетей.*
#
# *По данному критерию можно получить **2 балла** только при условии осуществления сравнительного анализа эффективности различных архитектур нейронных сетей внутри вашего проекта на одних и тех же данных. Самих архитектур должно быть не менее трёх; они должны значимо и осмысленно друг от друга отличаться; их использование, как и настройка гиперпараметров, должны быть подробно описаны и обоснованы. Кроме того, в рамках сравнительного анализа должны быть получены и сформулированы явные, значимые выводы о сравнительной эффективности той или иной архитектуры.*
#
# *По данному критерию можно получить **максимальный балл в 3 балла** только при условии корректного и обоснованного применения инструментов/подходов/библиотек для построения моделей, не рассматривавшихся в рамках соответствующих лекций и семинаров. Кроме того, **максимальный балл в 3 балла** по данному критерию недостижим без логирования экспериментов в соответствии с требованиями **Критерия 5**. При этом ожидается, что каждая из сравниваемых архитектур залогирована отдельным запуском с сохранением параметров архитектуры и обучения, метрик качества в разрезе эпох, а также артефакта обученной модели, позволяющего воспроизвести её предсказания без повторного обучения.*

# %% [markdown]
# ### Критерий 5. Инструменты промышленной разработки (до 1,5 баллов)
#
# Данный критерий оценивает, насколько грамотно и профессионально команда организовала процесс совместной разработки и обеспечила воспроизводимость своих экспериментов. В рамках этого критерия рассматриваются две составляющие: оформление репозитория GitHub и логирование экспериментов.
#
# *По данному критерию можно получить **0,5 балла** при выполнении всех следующих требований к репозиторию GitHub:*
#
# - наличие файла `README.md` с описанием проекта, используемых данных и структуры репозитория — после прочтения этого файла у стороннего человека не должно остаться вопросов о том, что делает проект и как в нём разобраться;
# - наличие файла `.gitignore`;
# - осмысленная структура репозитория: код организован по директориям, понятно, где лежат данные, где модели, где ноутбуки;
# - коммиты делаются осмысленно и регулярно по ходу работы над проектом, с понятными комментариями — по истории репозитория должно быть видно, что команда работала совместно на протяжении всего времени, а не залила всё в одном коммите накануне дедлайна.
#
# *По данному критерию можно получить **1 балл** при дополнительном выполнении следующего условия: все эксперименты с моделями — как на табличных, так и на неструктурированных данных — залогированы с использованием специализированного инструмента логирования экспериментов (например, MLflow, Weights & Biases, ClearML, DagsHub или аналогичного). Каждый эксперимент должен быть зафиксирован отдельным запуском и содержать: параметры модели и обучения, метрики качества — для табличных задач в целом по выборке, для задач на неструктурированных данных дополнительно в разрезе эпох, — а также артефакт обученной модели, позволяющий воспроизвести её предсказания без повторного обучения. Хранение файлов моделей исключительно напрямую в репозитории без привязки к системе логирования не засчитывается.*
#
# *По данному критерию можно получить **1,5 балла** при дополнительном выполнении следующего условия: в системе логирования сохранены также данные, использованные при обучении и валидации моделей, — таким образом, чтобы любой эксперимент можно было полностью воспроизвести, имея доступ только к системе логирования, без необходимости искать данные отдельно.*

# %% [markdown]
# # Первичная обработка данных / EDA

# %% [markdown]
# ## Постановка задачи

# %% [markdown]
# В рамках проекта мы рассмотрим прототип системы мониторинга лесных пожаров.
#
# **Описание датасета**
#
# Датасет содержит данные о погодных условиях, характеристиках окружающей среды и параметрах пожарной опасности в различных географических точках. Каждое наблюдение включает метеорологические, экологические и географические показатели, а также характеристики пожарного события.
#
# **Источник данных**
#
# Kaggle - https://www.kaggle.com/datasets/vijayaragulvr/wildfire-prediction
#
#
# В рамках табличной части наша задача регрессия. Нам необходимо по погодным, экологическим и географическим признакам оценить интенсивность пожарного события - показатель frp (Fire Radiative Power), который отражает радиационную мощность пожара и может рассматриваться как численная характеристика его интенсивности (чем выше значение frp, тем потенциально серьёзнее пожар).
#
# **Целевая переменная**
#
# frp - радиационная мощность пожара: непрерывная числовая переменная

# %% [markdown]
# ## Загрузка и первичный обзор данных

# %% [markdown]
# Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Загрузим датасет

# %%
data = pd.read_csv("/content/final_dataset.csv")

# %% [markdown]
# Размерность и первые строки

# %%
print("Размер данных:")
data.shape

# %%
print("Первые 5 строк:")
data.head()

# %% [markdown]
# Типы данных и признаки

# %%
print("Типы данных:")
data.dtypes

# %%
print("Информация о датасете:")
data.info()

# %% [markdown]
# Описательные статистики

# %%
print("Описательная статистика:")
data.describe()

# %% [markdown]
# Вывод: По результатам первичного обзора видно, что датасет содержит табличные числовые признаки, описывающие погодные, экологические и географические условия наблюдений. Целевая переменная frp является непрерывной числовой величиной, поэтому наша дальнейшая задача - регрессия.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Очистка данных

# %% [markdown]
# Переведем бинарные столбцы в тип данных int

# %%
data["daynight_N"] = data["daynight_N"].astype(int)
data["occured"] = data["occured"].astype(int)

# %% [markdown]
# Посмотрим на дубликаты

# %%
dupl=data.duplicated().sum()
print('Полных дубликатов:', dupl)

# %% [markdown]
# Посмотрим на пропуски

# %%
data.isna().sum()

# %%
miss=data.isna().sum().sum()
print('Пропусков в данных:', miss)

# %% [markdown]
# В датасете не обнаружено пропущенных значений и дубликатов.

# %% [markdown]
# ## Univariate analysis

# %% [markdown]
# ### Анализ целевой переменной

# %% [markdown]
# frp показывает интенсивность пожара, значение числовое

# %%
data['frp'].describe()

# %%
fig=px.histogram(data,x='frp',title='Распределение frp')
fig.show()

# %%
fig=px.box(data,x='frp',title='Боксплот frp')
fig.show()

# %% [markdown]
# Распределение frp сильно скошено вправо, много маленьких значений, но есть и отдельные очень большие. Для пожаров это нормально, так как интенсивные пожары встречаются реже.

# %% [markdown]
# ### Анализ признака occured

# %% [markdown]
# occured показывает был ли пожар или нет, это бинарный признак

# %%
data['occured'].value_counts()

# %%
data['occured'].value_counts(normalize=True).round(4)

# %%
fig=px.pie(data,names='occured',title='Доли классов целевой переменной')
fig.update_traces(textinfo='percent+label+value')
fig.show()

# %% [markdown]
# Переменная occured почти идеально сбалансирована, значений класса 0 и класса 1 примерно поровну

# %% [markdown]
# ### Анализ признака daynight_N

# %% [markdown]
# daynight_N это бинарный признак, показывает днем или ночью было зафиксировано наблюдение

# %%
data['daynight_N'].describe()

# %%
data['daynight_N'].value_counts()

# %%
data['daynight_N'].value_counts(normalize=True).round(4)

# %%
labels=data['daynight_N'].map({0:'День',1:'Ночь'})
fig=px.pie(names=labels,title='Распределение наблюдений по времени суток')
fig.update_traces(textinfo='percent+label+value')
fig.show()

# %% [markdown]
# Большая часть наблюдений относится к дневным, ночных сильно меньше, это нормально, потому что пожары чаще происходят и фиксируются днем, чем ночью

# %% [markdown]
# ### Анализ числовых признаков

# %%
num_cols = [
    'lat',
    'lon',
    'fire_weather_index',
    'pressure_mean',
    'wind_direction_mean',
    'wind_direction_std',
    'solar_radiation_mean',
    'dewpoint_mean',
    'cloud_cover_mean',
    'evapotranspiration_total',
    'humidity_min',
    'temp_mean',
    'temp_range',
    'wind_speed_max',
    'frp'
]

# %% [markdown]
# #### Анализ признака lat

# %% [markdown]
# Признак отражает широту

# %%
data['lat'].describe()

# %%
fig=px.histogram(data,x='lat',title='Распределение lat')
fig.show()

# %%
fig=px.box(data,x='lat',title='Боксплот lat')
fig.show()

# %% [markdown]
# Значения идут в широком диапазоне, значит данные собраны из разных регионов, это важно, потому что риск пожара сильно зависит от региона и климата

# %% [markdown]
# #### Анализ признака lon

# %% [markdown]
# Признак отражает долготу

# %%
data['lon'].describe()

# %%
fig=px.histogram(data,x='lon',title='Распределение lon')
fig.show()

# %%
fig=px.box(data,x='lon',title='Боксплот lon')
fig.show()

# %% [markdown]
# Аналогично, у lon широкий диапазон, потому что датасет покрывает разные регионы

# %% [markdown]
# #### Анализ признака fire_weather_index

# %% [markdown]
# fire_weather_index показывает пожарную опасность по погодным условиям

# %%
data['fire_weather_index'].describe()

# %%
fig=px.histogram(data,x='fire_weather_index',title='Распределение fire_weather_index')
fig.show()

# %%
fig=px.box(data,x='fire_weather_index',title='Боксплот fire_weather_index')
fig.show()

# %% [markdown]
# Распределение скошено вправо, но есть отдельные высокие значения

# %% [markdown]
# #### Анализ признака pressure_mean

# %% [markdown]
# pressure_mean показывает среднее атмосферное давление

# %%
data['pressure_mean'].describe()

# %%
fig=px.histogram(data,x='pressure_mean',title='Распределение pressure_mean')
fig.show()

# %%
fig=px.box(data,x='pressure_mean',title='Боксплот pressure_mean')
fig.show()

# %% [markdown]
# Видим, что распределение скошено влево, при этом есть отдельные низкие значения

# %% [markdown]
# #### Анализ признака wind_direction_mean

# %% [markdown]
# wind_direction_mean показывает среднее направление ветра в градусах

# %%
data['wind_direction_mean'].describe()

# %%
fig=px.histogram(data,x='wind_direction_mean',title='Распределение wind_direction_mean')
fig.show()

# %%
fig=px.box(data,x='wind_direction_mean',title='Боксплот wind_direction_mean')
fig.show()

# %% [markdown]
# wind_direction_mean особенность: 0 и 360 градусов это почти одно и то же направление, а для модели как обычные числа они выглядят далеко, дальше в feature engineering его можно заменить на синус и косинус.

# %% [markdown]
# #### Анализ признака wind_direction_std

# %% [markdown]
# wind_direction_std показывает разброс направления ветра

# %%
data['wind_direction_std'].describe()

# %%
fig=px.histogram(data,x='wind_direction_std',title='Распределение wind_direction_std')
fig.show()

# %%
fig=px.box(data,x='wind_direction_std',title='Боксплот wind_direction_std')
fig.show()

# %% [markdown]
# Разброс направления ветра у наблюдений разный

# %% [markdown]
# #### Анализ признака solar_radiation_mean

# %% [markdown]
# solar_radiation_mean показывает средний уровень солнечной радиации

# %%
data['solar_radiation_mean'].describe()

# %%
fig=px.histogram(data,x='solar_radiation_mean',title='Распределение solar_radiation_mean')
fig.show()

# %%
fig=px.box(data,x='solar_radiation_mean',title='Боксплот solar_radiation_mean')
fig.show()

# %% [markdown]
# Большая часть значений находится в основном диапазоне, но есть и более высокие наблюдения

# %% [markdown]
# #### Анализ признака dewpoint_mean

# %% [markdown]
# dewpoint_mean показывает среднюю точку росы

# %%
data['dewpoint_mean'].describe()

# %%
fig=px.histogram(data,x='dewpoint_mean',title='Распределение dewpoint_mean')
fig.show()

# %%
fig=px.box(data,x='dewpoint_mean',title='Боксплот dewpoint_mean')
fig.show()

# %% [markdown]
# #### Анализ признака cloud_cover_mean

# %% [markdown]
# cloud_cover_mean показывает среднюю облачность

# %%
data['cloud_cover_mean'].describe()

# %%
fig=px.histogram(data,x='cloud_cover_mean',title='Распределение cloud_cover_mean')
fig.show()

# %%
fig=px.box(data,x='cloud_cover_mean',title='Боксплот cloud_cover_mean')
fig.show()

# %% [markdown]
# #### Анализ признака evapotranspiration_total

# %% [markdown]
# evapotranspiration_total показывает суммарное испарение

# %%
data['evapotranspiration_total'].describe()

# %%
fig=px.histogram(data,x='evapotranspiration_total',title='Распределение evapotranspiration_total')
fig.show()

# %%
fig=px.box(data,x='evapotranspiration_total',title='Боксплот evapotranspiration_total')
fig.show()

# %% [markdown]
# #### Анализ признака humidity_min

# %% [markdown]
# humidity_min показывает минимальную влажность

# %%
data['humidity_min'].describe()

# %%
fig=px.histogram(data,x='humidity_min',title='Распределение humidity_min')
fig.show()

# %%
fig=px.box(data,x='humidity_min',title='Боксплот humidity_min')
fig.show()

# %% [markdown]
# #### Анализ признака temp_mean

# %% [markdown]
# temp_mean показывает среднюю температуру

# %%
data['temp_mean'].describe()

# %%
fig=px.histogram(data,x='temp_mean',title='Распределение temp_mean')
fig.show()

# %%
fig=px.box(data,x='temp_mean',title='Боксплот temp_mean')
fig.show()

# %% [markdown]
# #### Анализ признака temp_range

# %% [markdown]
# temp_range показывает диапазон температуры

# %%
data['temp_range'].describe()

# %%
fig=px.histogram(data,x='temp_range',title='Распределение temp_range')
fig.show()

# %%
fig=px.box(data,x='temp_range',title='Боксплот temp_range')
fig.show()

# %% [markdown]
# #### Анализ признака wind_speed_max

# %% [markdown]
# wind_speed_max показывает максимальную скорость ветра

# %%
data['wind_speed_max'].describe()

# %%
fig=px.histogram(data,x='wind_speed_max',title='Распределение wind_speed_max')
fig.show()

# %%
fig=px.box(data,x='wind_speed_max',title='Боксплот wind_speed_max')
fig.show()

# %% [markdown]
# ### Проверка выбросов по IQR

# %% [markdown]
# Дополнительно посмотрим, у каких признаков есть сильно отличающиеся значения от основной части распределения.

# %%
rows=[]
for col in num_cols:
    q1= data[col].quantile(0.25)
    q3=data[col].quantile(0.75)
    spread=q3-q1
    minv=q1-1.5*spread
    maxv=q3+1.5*spread
    mask=(data[col] <minv)|(data[col]>maxv)
    rows.append([col,round(minv, 2),round(maxv, 2),mask.sum(),round(mask.mean()*100, 2)])

outliers_table=pd.DataFrame(rows,columns=['column','minv','maxv', 'count','percent'])
outliers_table.sort_values('percent',ascending=False)

# %% [markdown]
# Больше всего выбросов наблюдается у frp, fire_weather_index, evapotranspiration_total, wind_speed_max и solar_radiation_mean. Это совпадает с тем, что было видно на гистограммах и боксплотах.
# При этом для погодных и пожарных данных такие значения не обязатеьно ошибочны, тк для пожаров нужны редкие экстремальные условия

# %% [markdown]
# ### Проверка асимметрии распределений

# %%
skew_table=data[num_cols].skew().sort_values(ascending=False).reset_index()
skew_table.columns=['feature','skewness']
skew_table

# %% [markdown]
# frp, fire_weather_index и wind_speed_max сильнее всего скошены вправо, обычная модель может сильнo реагировать на отдельные большие значения, поэтому в фичер инджиниренге добавим логарифмированные версии.

# %% [markdown]
# ###Выводы по univariate анализу

# %% [markdown]
# Целевая переменная почти сбалансирована.
# По погодным признакам видно, что часть переменных имеет выбросы и асимметричные распределения. Это сильнее заметно у frp, fire_weather_index и wind_speed_max. Такие значения не стоит сразу удалять, потому что в случае с задачей с  пожарами экстремальные погодные условия могут быть как раз очень важны.
# Координаты lat и lon тоже дают много выбросов , но для географических признаков это значит что данные относятся к разным регионам, поэтому удалять выбросы координат не нужно.
# Самыми важными признаками на этом этапе можно выделить fire_weather_index, humidity_min, temp_mean, wind_speed_max, solar_radiation_mean и frp. При этом frp нужно использовать осторожно, потому что он может быть связан уже с фактом обнаруженного пожара.
# Перед обучением модели нужно будет масштабировать признаки, также, например, в feature engineering можно добавить логарифмированные версии скошенных признаков и несколько погодных индексов, которые объединяют температуру, влажность, ветер и солнечную радиацию.

# %% [markdown]
# ## Multivariate analysis

# %% [markdown]
# ### Корреляция признаков с целевой переменной

# %%
target = 'frp'

target_corr = (data.corr(numeric_only=True)[target].drop(target).sort_values(key=lambda x: x.abs(), ascending=False))
#target_corr

# %%
import plotly.express as px

target_corr = target_corr.sort_values(ascending=True)

fig = px.bar(target_corr,
             x=target_corr,
             y=target_corr.index,
             labels = {'x': 'Корреляция с target', 'y': 'Признак'},
             title ='Корреляция признаков с целевой переменной')

fig.show()

# %% [markdown]
# Среди признаков наиболее заметная связь с frp наблюдается у occured, daynight_N, wind_speed_max, solar_radiation_mean, fire_weather_index, evapotranspiration_total и temp_range. Это выглядит предметно объяснимо, так как интенсивность пожарного события может быть дейтсвительно связана с фактом пожара, временем наблюдения, ветровыми условиями, уровнем солнечной радиации, пожарной опасностью и сухостью окружающей среды.
#
# Стоит отметить, что значения корреляций большинства признаков невысокие. Это может значить, что интенсивность пожара не объясняется одним отдельным фактором, а, скорее всего всего, зависит от совместного влияния комбинации признаков.

# %% [markdown]
# ### Корреляционная матрица признаков

# %%
corr_matrix = data.corr(numeric_only=True)

fig = px.imshow(corr_matrix,
                text_auto='.2f',
                color_continuous_scale='RdBu_r',
                title='Корреляционная матрица признаков')

fig.update_layout(width=900, height=900)

fig.show()

# %%
high_corr = []
cols = corr_matrix.columns

for i in range(len(cols)):
    for j in range(i + 1, len(cols)):

        col1 = cols[i]
        col2 = cols[j]

        value = corr_matrix.loc[col1, col2]

        if np.abs(value) > 0.7:
            high_corr.append([col1, col2, value])

high_corr_df = pd.DataFrame(high_corr, columns=['Признак 1', 'Признак 2', 'Корреляция'])

high_corr_df

# %% [markdown]
# Корреляционная матрица показывает, что в данных есть несколько сильно коррелирующих между собой признаков. Наиболее высокая положительная корреляция наблюдается между `fire_weather_index` (индекс пожарной опасности) и `evapotranspiration_total` (суммарная эвапотранспирация): корреляция составляет около 0.84. Это выглядит логично, так как оба признака отражают погодные условия, связанные с сухостью среды и повышенным риском пожара.
#
# Также заметная положительная связь наблюдается между `dewpoint_mean` (средняя точка росы) и `humidity_min` (минимальная влажность). Их корреляция составляет 0.72.
#
# Отрицательная корреляция между `humidity_min` (минимальная влажность) и `temp_range` (диапазон температур) составляет около -0.71. Это может значить, что при большей разнице температуры (максимальной и минимальной), минимальная влажность воздуха - ниже.

# %% [markdown]
# ### Распределение признаков в зависимости от значения целевой переменной

# %%
features = ['fire_weather_index', #признаки, сильнее всего заметные по корреляции с целевой переменной
            'humidity_min',
            'evapotranspiration_total',
            'temp_range',
            'solar_radiation_mean',
            'wind_speed_max']

# %%
for i in features:

    fig = px.box(data,
                 x=data['occured'].map({0: '0 — пожара нет', 1: '1 — пожар есть'}),
                 y = i,
                 title=f'Распределение признака {i} по целевой переменной',
                 labels={'occured': 'Возникновение пожара', i: i})

    fig.show()

# %%
data.groupby('occured')[features].mean()

# %%
data.groupby('occured')[features].median()

# %% [markdown]
# Сравнение распределений признаков по классам `occured = 0` (пожара нет) и `occured = 1` (пожар есть) показало, что классы отличаются, но заметно пересекаются. А значит, ни один отдельный признак сам по себе не позволит полностью разделить наблюдения с пожаром и без пожара.
#
# Для наблюдений с пожаром характерны более высокие значения `fire_weather_index` (индекс пожарной опасности), `evapotranspiration_total` (суммарная эвапотранспирация), `temp_range` (диапазон температур), `solar_radiation_mean` (средняя солнечная радиация) и `wind_speed_max` (максимальная скорость ветра). При этом `humidity_min` (минимальная влажность) в классе с пожаром ниже, что логично, так как более сухие условия повышают риск возникновения пожара.
#
# Вывод: для дальнейшего моделирования важно учитывать совместное влияние нескольких погодных признаков.

# %% [markdown]
# ### Парный анализ признаков и дополнительное сравнение по факту пожара

# %%
data.shape

# %% [markdown]
# Для построения scatter plot используем случайные подвыборки из 10 000 и 50000 наблюдений.

# %%
sample_data1 = data.sample(10000, random_state = 5)
sample_data2 = data.sample(50000, random_state = 5)

# %% [markdown]
# Для анализа были выбраны признаки, которые хорошо интерпретируются с точки зрения пожарной опасности: минимальная влажность, индекс пожарной опасности и географические координаты. Дополнительно точки окрашены по признаку `occured`, чтобы сравнить наблюдения с пожаром и без пожара.
#
# Так как для возникновения пожара особенно важны погодные условия: сухость, температура, солнечная радиацией и ветер -  то для парного анализа выбраны две пары признаков.
#
# Первая пара — `humidity_min` и `fire_weather_index`, так как она отражает совместное влияние влажности и общего индекса пожарной опасности.
#
# Вторая пара — `lat` и `lon` - координаты, позволяющие проверить географическое распределение наблюдений.

# %% [markdown]
# ### Минимальная влажность и индекс пожарной опасности

# %%
fig = px.scatter(sample_data1, x = 'humidity_min', y = 'fire_weather_index',
                 color = sample_data1['occured'].map({0: '0 — пожара нет', 1: '1 — пожар есть'}),
                 opacity = 0.4,
                 title = 'Связь минимальной влажности и индекса пожарной опасности',
                 labels = {'humidity_min': 'Минимальная влажность',
                         'fire_weather_index': 'Индекс пожарной опасности',
                         'color': 'Возникновение пожара'})

fig.show()

# %% [markdown]
# На графике связи `humidity_min` (минимальной влажности) и `fire_weather_index` (индекса пожарной опасности) видно, что между признаками есть выраженная обратная зависимость, при снижении минимальной влажности индекс пожарной опасности растёт.
#
# При этом точки двух классов `occured = 0` (пожара нет) и `occured = 1` (пожар есть) заметно пересекаются. Это значит, что даже сочетание низкой влажности и высокого индекса пожарной опасности не даёт полного разделения классов.
#
# Наблюдения пожара чаще встречаются в зоне с более низкой влажностью и повышенным индексом пожарной опасности, что логично.

# %% [markdown]
# ### Географическое распределение наблюдений

# %%
fig = px.scatter(sample_data2,
                 x = 'lon',
                 y = 'lat',
                 color = sample_data2['occured'].map({0: '0 — пожара нет', 1: '1 — пожар есть'}),
                 opacity = 0.3,
                 title = 'Географическое распределение наблюдений',
                 labels = {'lon': 'Долгота','lat': 'Широта', 'color': 'Возникновение пожара'})

fig.update_layout(height = 700)

fig.show()

# %% [markdown]
# Из графика по координатам видно, что данные охватывают разные регионы, а наблюдения с пожаром и без пожара много где располагаются рядом друг с другом.
#
# Это может значить, что географические координаты могут быть полезны для модели, так как риск пожара зависит от территории и климатической зоны.

# %% [markdown]
# ### Итоговые выводы multivariate analysis

# %% [markdown]
# В ходе multivariate analysis были рассмотрены связи признаков с целевой переменной frp, взаимосвязи между самими признаками, а также дополнительные различия распределений признаков для наблюдений с пожаром и без пожара.
#
# Корреляционный анализ показал, что с фактом возникновения пожара связаны прежде всего погодные признаки и в целом пожары чаще соответствуют более сухим и солнечным погодным условиям.
#
# Корреляционная матрица показала наличие несколmких сильно коррелирующих между собой признаков (>0,7): `fire_weather_index` с `evapotranspiration_total`, `humidity_min` с `dewpoint_mean` и `temp_range`.
#
# Анализ boxplot и scatter plot показал, что классы `occured = 0` и `occured = 1` отличаются, но заметно пересекаются. Следовательно, один отдельно взятый признак или простая пара признаков не позволят полностью отделить пожары от наблюдений без пожара.
#
# На этапе EDA сильно скоррелированные признаки не удалялись.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Создадим копию датасета

# %%
df_fe=data.copy()

# %% [markdown]
# ### Логарифмирование целевой переменной

# %%
df_fe['frp_log']=np.log1p(df_fe['frp'])

# %% [markdown]
# Создаём frp_log, потому что в унивариантном анализе было видно, что распределение фрп сильно скошено вправо, лог поможет сгладить большие значения

# %% [markdown]
# ### Удаление occured

# %% [markdown]
# Удалим признак occured тк он напрямую связан с фактом возникновения пожара

# %%
df_fe=df_fe.drop(columns=['occured'])

# %% [markdown]
# ### Преобразование направления ветра

# %% [markdown]
# Направление циклично и 0 и 360 градусов это примерно одно и то же направление, но для модели именно числа выглядят сильно разными, поэтому заменим их на синусы и косинусы

# %%
angle=np.deg2rad(df_fe['wind_direction_mean'])
df_fe['wind_direction_sin']=np.sin(angle)
df_fe['wind_direction_cos']=np.cos(angle)
df_fe=df_fe.drop(columns=['wind_direction_mean'])

# %% [markdown]
# ### Логарифмирование признаков с ассиметрией

# %% [markdown]
# В унивариантном анализе увидели, что у wind_speed_max и fire_weather_index распределение скошено вправо. Многие значения находится в нижней части диапазона, справа есть более редкие высокие значения, добавим логарифмированные версии, исходные удалять не будем

# %%
df_fe['wind_speed_max_log']=np.log1p(df_fe['wind_speed_max'])
df_fe['fire_weather_index_log']=np.sign(df_fe['fire_weather_index'])*np.log1p(np.abs(df_fe['fire_weather_index']))

# %% [markdown]
# Используем signed log для fire_weather_index, тк встречаются отрицательные значения

# %% [markdown]
# ### Индекс жаркой и сухой погоды

# %% [markdown]
# Признаки temp_mean и humidity_mean можно рассмотреть вместе, в мультивариантном анализе было видно, что влажность и температурные признаки связаны с уровнем пожарного риска

# %%
df_fe['hot_dry_index']=df_fe['temp_mean']/(df_fe['humidity_min']+1)

# %% [markdown]
# +1 делаем, чтобы не было деления на ноль, hot_dry_index создан как отношение средней температуры к минимальной влажности. Смысл признака в том, что одинаковая температура может описывать разные условия при разной влажности

# %% [markdown]
# ### Индекс сухости с учетом ветра

# %%
df_fe['wind_dry_index']=df_fe['wind_speed_max']/(df_fe['humidity_min']+1)

# %% [markdown]
# Новый признак показывает силу ветра относительно сухости воздуха, это может быть более важно когда ветер высокий при низкой влажности

# %% [markdown]
# Сохраняю прост файлом

# %%
df_fe.to_csv('final_dataset_fe.csv',index=False)

# %%
from google.colab import files
files.download('final_dataset_fe.csv')

# %% [markdown]
# ### Вывод по feature engineering

# %% [markdown]
# Создали frp_log, потому что в унивариантном анализе было видно, что распределение frp сильно скошено вправо. Также удалили occured, так как этот признак показывает факт наличия пожара и слишком сильно связан с целевой переменной.
# wind_direction_mean преобразовали в wind_direction_sin и wind_direction_cos, чтобы модель не воспринимала направление ветра просто как обычное число. Добавили wind_speed_max_log и fire_weather_index_log, потому что у этих признаков была правосторонняя асимметрия. Из составных добавили hot_dry_index и wind_dry_index, чтобы показать сочетание температуры с влажностью и ветра с влажностью.

# %% [markdown]
# ## Итоговые выводы EDA

# %% [markdown]
# В ходе EDA мы провели анализ табличного датасета для задачи прогнозирования интенсивности пожара. Наш датасет не содержит пропущенных значений и полных дубликатов.
#
# Целевая переменная frp имеет выраженную правостороннюю асимметрию и содержит экстремально высокие значения. Поэтому для дальнейшего моделирования мы будем использовать логарифм fpr - `frp_log`.
#
# Анализ признаков также показал, что интенсивность пожара связана не с одним отдельным фактором, а с комбинацией погодных, экологических и географических условий. Наиболее важными выглядят признаки, связанные с влажностью, температурой, ветром, солнечной радиацией, испарением и индексом пожарной опасности.
#
# Корреляционная матрица выявила несколько сильно связанных между собой признаков, однако на этапе EDA они не удалялись.
#
# По результатам Feature Engineering мы создали дополнительные признаки и трансформировали имеющиеся: логарифмированные версии скошенных переменных, циклическое кодирование направления ветра и составные погодные индексы.
